# %%
# doc -----------

# %%
#import modin.pandas as pd
# importing lib
import pandas as pd

# %% [markdown]
# # loading the file

# %%
data=pd.read_csv('/Users/sandippandey/Downloads/assignment_file/findata.csv',skiprows=[0],header=0,encoding='latin-1')
data
# Out:
#     Year  WHOLE COUNTRY Population 31 Dec  \
# 0   1990                          4998478
# 1   1991                          5029002
# 2   1992                          5054982
# 3   1993                          5077912
# 4   1994                          5098754
# 5   1995                          5116826
# 6   1996                          5132320
# 7   1997                          5147349
# 8   1998                          5159646
# 9   1999                          5171302
# 10  2000                          5181115
# 11  2001                          5194901
# 12  2002                          5206295
# 13  2003                          5219732
# 14  2004                          5236611
# 15  2005                          5255580
# 16  2006                          5276955
# 17  2007                          5300484
# 18  2008                          5326314
# 19  2009                          5351427
# 20  2010                          5375276
# ...

# %%
#samples of the observation

# %%
#checking the number of observations in the dataset
(rows,col)=data.shape
print(f"no. of rows{rows},cols{col}")
# Out:
# no. of rows30,cols6865

# %%
#checking the datatype of each columns and also changed the year column to datetime format
data.dtypes
# Out:
# Year                                                                                                                 int64
# WHOLE COUNTRY Population 31 Dec                                                                                      int64
# WHOLE COUNTRY Citizens of foreign countries                                                                          int64
# WHOLE COUNTRY Persons born abroad                                                                                    int64
# WHOLE COUNTRY Foreign-language speakers                                                                              int64
#                                                                                                                     ...
# FI200 Åland Share of persons with foreign background , %                                                           float64
# FI200 Åland Share of foreign citizens among foreign citizens in the whole country, %                               float64
# ...

# %%
# converting year column to datetime format
data['Year']=pd.to_datetime(data['Year'],format='%Y')
data.Year
# Out:
# 0    1990-01-01
# 1    1991-01-01
# 2    1992-01-01
# 3    1993-01-01
# 4    1994-01-01
# 5    1995-01-01
# 6    1996-01-01
# 7    1997-01-01
# 8    1998-01-01
# 9    1999-01-01
# 10   2000-01-01
# 11   2001-01-01
# 12   2002-01-01
# 13   2003-01-01
# 14   2004-01-01
# 15   2005-01-01
# 16   2006-01-01
# 17   2007-01-01
# 18   2008-01-01
# 19   2009-01-01
# 20   2010-01-01
# 21   2011-01-01
# 22   2012-01-01
# 23   2013-01-01
# 24   2014-01-01
# 25   2015-01-01
# 26   2016-01-01
# 27   2017-01-01
# 28   2018-01-01
# 29   2019-01-01
# Name: Year, dtype: datetime64[ns]

# %%
#setting Year column as an index
data=data.set_index('Year')
data
# Out:
#             WHOLE COUNTRY Population 31 Dec  \
# Year
# 1990-01-01                          4998478
# 1991-01-01                          5029002
# 1992-01-01                          5054982
# 1993-01-01                          5077912
# 1994-01-01                          5098754
# 1995-01-01                          5116826
# 1996-01-01                          5132320
# 1997-01-01                          5147349
# 1998-01-01                          5159646
# 1999-01-01                          5171302
# 2000-01-01                          5181115
# 2001-01-01                          5194901
# 2002-01-01                          5206295
# 2003-01-01                          5219732
# 2004-01-01                          5236611
# 2005-01-01                          5255580
# 2006-01-01                          5276955
# 2007-01-01                          5300484
# 2008-01-01                          5326314
# 2009-01-01                          5351427
# ...

# %%
data.describe(include='all')
# Out:
#        WHOLE COUNTRY Population 31 Dec  \
# count                     3.000000e+01
# mean                      5.273639e+06
# std                       1.628724e+05
# min                       4.998478e+06
# 25%                       5.150423e+06
# 50%                       5.246096e+06
# 75%                       5.420322e+06
# max                       5.525292e+06
#
#        WHOLE COUNTRY Citizens of foreign countries  \
# count                                    30.000000
# mean                                 134037.533333
# std                                   71799.712212
# min                                   26255.000000
# 25%                                   81715.000000
# 50%                                  111099.000000
# 75%                                  192416.500000
# max                                  267629.000000
#
#        WHOLE COUNTRY Persons born abroad  \
# count                          30.000000
# mean                       202557.033333
# ...

# %% [markdown]
# <b> This function gives you several useful things all at the same time. For example, you will get the  mean, count, minimum and maximum values and the standard deviation. This is very useful, especially in exploratory data analysis</b>

# %%
# putting commas in numbers for easy readable format
data=data.applymap(lambda x: "{:,}".format(x))
data
# Out:
#            WHOLE COUNTRY Population 31 Dec  \
# Year
# 1990-01-01                       4,998,478
# 1991-01-01                       5,029,002
# 1992-01-01                       5,054,982
# 1993-01-01                       5,077,912
# 1994-01-01                       5,098,754
# 1995-01-01                       5,116,826
# 1996-01-01                       5,132,320
# 1997-01-01                       5,147,349
# 1998-01-01                       5,159,646
# 1999-01-01                       5,171,302
# 2000-01-01                       5,181,115
# 2001-01-01                       5,194,901
# 2002-01-01                       5,206,295
# 2003-01-01                       5,219,732
# 2004-01-01                       5,236,611
# 2005-01-01                       5,255,580
# 2006-01-01                       5,276,955
# 2007-01-01                       5,300,484
# 2008-01-01                       5,326,314
# 2009-01-01                       5,351,427
# 2010-01-01                       5,375,276
# ...

# %%
datat=data.T
datat.reset_index()
da=datat.index.str.extract(r'(^w+\sw+)')
da
# Out:
#         0
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ...   ...
# 6859  NaN
# 6860  NaN
# 6861  NaN
# 6862  NaN
# 6863  NaN
#
# [6864 rows x 1 columns]

# %%
data.isnull().sum()
#checking the null values in the dataset and we can see that there are no null values in the dataset
# Out:
# WHOLE COUNTRY Population 31 Dec                                                                                    0
# WHOLE COUNTRY Citizens of foreign countries                                                                        0
# WHOLE COUNTRY Persons born abroad                                                                                  0
# WHOLE COUNTRY Foreign-language speakers                                                                            0
# WHOLE COUNTRY Persons with foreign background                                                                      0
#                                                                                                                   ..
# FI200 Åland Share of persons with foreign background , %                                                           0
# FI200 Åland Share of foreign citizens among foreign citizens in the whole country, %                               0
# ...

# %%
wholecountry=data[data.columns[data.columns.str.startswith('WHOLE')]]
Tampere=data[data.columns[data.columns.str.startswith('Tampere')]]
Turku=data[data.columns[data.columns.str.startswith('Turku')]]
Helsinki=data[data.columns[data.columns.str.startswith('Helsinki')]]
Oulu=data[data.columns[data.columns.str.startswith('Oulu')]]

# %%
new_df=pd.concat([Tampere,Turku,Helsinki,Oulu],axis=1)
new_df
# Out:
#                               Tampere Population 31 Dec  \
# 1970-01-01 00:00:00.000000000                       NaN
# 1970-01-01 00:00:00.000000001                       NaN
# 1970-01-01 00:00:00.000000002                       NaN
# 1970-01-01 00:00:00.000000003                       NaN
# 1970-01-01 00:00:00.000000004                       NaN
# 1970-01-01 00:00:00.000000005                       NaN
# 1970-01-01 00:00:00.000000006                       NaN
# 1970-01-01 00:00:00.000000007                       NaN
# 1970-01-01 00:00:00.000000008                       NaN
# 1970-01-01 00:00:00.000000009                       NaN
# 1970-01-01 00:00:00.000000010                       NaN
# 1970-01-01 00:00:00.000000011                       NaN
# 1970-01-01 00:00:00.000000012                       NaN
# 1970-01-01 00:00:00.000000013                       NaN
# 1970-01-01 00:00:00.000000014                       NaN
# 1970-01-01 00:00:00.000000015                       NaN
# ...

# %%
new_df.columns.str.title()
# Out:
# Index(['Tampere Population 31 Dec', 'Tampere Citizens Of Foreign Countries',
#        'Tampere Persons Born Abroad', 'Tampere Foreign-Language Speakers',
#        'Tampere Persons With Foreign Background',
#        'Tampere Share Of Foreign Citizens, %',
#        'Tampere Share Of Persons Born Abroad, %',
#        'Tampere Share Of Foreign-Language Speakers, %',
#        'Tampere Share Of Persons With Foreign Background , %',
#        'Tampere Share Of Foreign Citizens Among Foreign Citizens In The Whole Country, %',
#        'Tampere Share Of Persons Born Abroad Among Persons Born Abroad In The Whole Country, %',
#        'Tampere Share Of Foreign-Language Speakers Among Foreign-Language Speakers In The Whole Country, %',
#        'Tampere Share Of Persons With Foreign Background Among Persons With Foreign Backgr. In The Whole Country, %',
#        'Turku Population 31 Dec', 'Turku Citizens Of Foreign Countries',
# ...

# %%
Oulu['city']='Oulu'
#a=data.columns.str.replace(r'^[a-zA-Z]+\s[a-zA-Z]+','')
#a
Oulu
# Out:
# <ipython-input-21-1f0c6bdead81>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Oulu['city']='Oulu'
#            Oulu Population 31 Dec Oulu Citizens of foreign countries  \
# Year
# 1990-01-01                136,029                                572
# 1991-01-01                137,586                                759
# 1992-01-01                139,414                                951
# 1993-01-01                140,870                              1,123
# 1994-01-01                143,257                              1,223
# 1995-01-01                146,395                              1,317
# 1996-01-01                149,136                              1,374
# ...

# %%
a
# Out:
# Index([' Population 31 Dec', ' Citizens of foreign countries',
#        ' Persons born abroad', ' Foreign-language speakers',
#        ' Persons with foreign background', ' Share of foreign citizens, %',
#        ' Share of persons born abroad, %',
#        ' Share of foreign-language speakers, %',
#        ' Share of persons with foreign background , %',
#        ' Share of foreign citizens among foreign citizens in the whole country, %',
#        ...
#        'FI200 Åland Foreign-language speakers',
#        'FI200 Åland Persons with foreign background',
#        'FI200 Åland Share of foreign citizens, %',
#        'FI200 Åland Share of persons born abroad, %',
#        'FI200 Åland Share of foreign-language speakers, %',
#        'FI200 Åland Share of persons with foreign background , %',
#        'FI200 Åland Share of foreign citizens among foreign citizens in the whole country, %',
# ...

# %%
Oulu.reset_index(inplace=True)
Turku.reset_index(inplace=True)
Tampere.reset_index(inplace=True)
Helsinki.reset_index(inplace=True)
wholecountry.reset_index(inplace=True)

# %%
Oulu
# Out:
#          Year Oulu Population 31 Dec Oulu Citizens of foreign countries  \
# 0  1990-01-01                136,029                                572
# 1  1991-01-01                137,586                                759
# 2  1992-01-01                139,414                                951
# 3  1993-01-01                140,870                              1,123
# 4  1994-01-01                143,257                              1,223
# 5  1995-01-01                146,395                              1,317
# 6  1996-01-01                149,136                              1,374
# 7  1997-01-01                151,397                              1,483
# 8  1998-01-01                153,883                              1,594
# 9  1999-01-01                156,917                              1,668
# 10 2000-01-01                160,851                              1,783
# 11 2001-01-01                164,224                              1,970
# ...

# %%
Oulu.columns
# Out:
# Index(['Year', 'Oulu Population 31 Dec', 'Oulu Citizens of foreign countries',
#        'Oulu Persons born abroad', 'Oulu Foreign-language speakers',
#        'Oulu Persons with foreign background',
#        'Oulu Share of foreign citizens, %',
#        'Oulu Share of persons born abroad, %',
#        'Oulu Share of foreign-language speakers, %',
#        'Oulu Share of persons with foreign background , %',
#        'Oulu Share of foreign citizens among foreign citizens in the whole country, %',
#        'Oulu Share of persons born abroad among persons born abroad in the whole country, %',
#        'Oulu Share of foreign-language speakers among foreign-language speakers in the whole country, %',
#        'Oulu Share of persons with foreign background among persons with foreign backgr. in the whole country, %',
#        'city'],
#       dtype='object')

# %%
Oulu1=Oulu.groupby(["Year","city"])[['Oulu Population 31 Dec',
       'Oulu Citizens of foreign countries',
       'Oulu Persons born abroad', 'Oulu Foreign-language speakers',
       'Oulu Persons with foreign background',
       'Oulu Share of foreign citizens, %',
       'Oulu Share of persons born abroad, %',
       'Oulu Share of foreign-language speakers, %',
       'Oulu Share of persons with foreign background , %',
       'Oulu Share of foreign citizens among foreign citizens in the whole country, %',
       'Oulu Share of persons born abroad among persons born abroad in the whole country, %',
       'Oulu Share of foreign-language speakers among foreign-language speakers in the whole country, %',
       'Oulu Share of persons with foreign background among persons with foreign backgr. in the whole country, %',]].sum().unstack().swaplevel(0,1,1)
Oulu1
# Out:
# city                         Oulu                                     \
#            Oulu Population 31 Dec Oulu Citizens of foreign countries
# Year
# 1990-01-01                136,029                                572
# 1991-01-01                137,586                                759
# 1992-01-01                139,414                                951
# 1993-01-01                140,870                              1,123
# 1994-01-01                143,257                              1,223
# 1995-01-01                146,395                              1,317
# 1996-01-01                149,136                              1,374
# 1997-01-01                151,397                              1,483
# 1998-01-01                153,883                              1,594
# 1999-01-01                156,917                              1,668
# 2000-01-01                160,851                              1,783
# ...

# %%
# to multicolumns
Oul=Oulu.set_index(["Year","city"]).unstack().swaplevel(0,1,1)
Oul
Hel=Helsinki.set_index(["Year","city"]).unstack().swaplevel(0,1,1)
Hel
# Out:
# city       Helsinki                             \
#               index Helsinki Population 31 Dec
# Year
# 1990-01-01        0                    492,400
# 1991-01-01        1                    497,542
# 1992-01-01        2                    501,514
# 1993-01-01        3                    508,588
# 1994-01-01        4                    515,765
# 1995-01-01        5                    525,031
# 1996-01-01        6                    532,053
# 1997-01-01        7                    539,363
# 1998-01-01        8                    546,317
# 1999-01-01        9                    551,123
# 2000-01-01       10                    555,474
# 2001-01-01       11                    559,718
# 2002-01-01       12                    559,716
# 2003-01-01       13                    559,330
# 2004-01-01       14                    559,046
# 2005-01-01       15                    560,905
# 2006-01-01       16                    564,521
# 2007-01-01       17                    568,531
# ...

# %%
Tur=Turku.set_index(["Year","city"]).unstack().swaplevel(0,1,1)
whole=wholecountry.set_index(["Year","city"]).unstack().swaplevel(0,1,1)
Tam=Tampere.set_index(["Year","city"]).unstack().swaplevel(0,1,1)
Tam
# Out:
# city       Tampere                            \
#              index Tampere Population 31 Dec
# Year
# 1990-01-01       0                   172,560
# 1991-01-01       1                   173,797
# 1992-01-01       2                   174,859
# 1993-01-01       3                   176,149
# 1994-01-01       4                   179,251
# 1995-01-01       5                   182,742
# 1996-01-01       6                   186,026
# 1997-01-01       7                   188,726
# 1998-01-01       8                   191,254
# 1999-01-01       9                   193,174
# 2000-01-01      10                   195,468
# 2001-01-01      11                   197,774
# 2002-01-01      12                   199,823
# 2003-01-01      13                   200,966
# 2004-01-01      14                   202,932
# 2005-01-01      15                   204,337
# 2006-01-01      16                   206,368
# 2007-01-01      17                   207,866
# 2008-01-01      18                   209,552
# ...

# %%
new_data1=pd.concat([Oul,Tur,Hel,Tam,whole],axis=1)
new_data
# Out:
# city                         Tampere                                        \
#            Tampere Population 31 Dec Tampere Citizens of foreign countries
# Year
# 1990-01-01                   172,560                                   936
# 1991-01-01                   173,797                                 1,249
# 1992-01-01                   174,859                                 1,517
# 1993-01-01                   176,149                                 1,858
# 1994-01-01                   179,251                                 2,256
# 1995-01-01                   182,742                                 2,709
# 1996-01-01                   186,026                                 3,070
# 1997-01-01                   188,726                                 3,563
# 1998-01-01                   191,254                                 3,791
# 1999-01-01                   193,174                                 4,053
# ...

# %%
Oulu.set_index(["Year","city"]).stack().unstack([1,2])
# Out:
# city        Oulu                                                            \
#            index Oulu Population 31 Dec Oulu Citizens of foreign countries
# Year
# 1990-01-01     0                136,029                                572
# 1991-01-01     1                137,586                                759
# 1992-01-01     2                139,414                                951
# 1993-01-01     3                140,870                              1,123
# 1994-01-01     4                143,257                              1,223
# 1995-01-01     5                146,395                              1,317
# 1996-01-01     6                149,136                              1,374
# 1997-01-01     7                151,397                              1,483
# 1998-01-01     8                153,883                              1,594
# 1999-01-01     9                156,917                              1,668
# ...

# %%
bc["Oulu"]
# Out:
#             index Oulu Population 31 Dec Oulu Citizens of foreign countries  \
# Year
# 1990-01-01      0                136,029                                572
# 1991-01-01      1                137,586                                759
# 1992-01-01      2                139,414                                951
# 1993-01-01      3                140,870                              1,123
# 1994-01-01      4                143,257                              1,223
# 1995-01-01      5                146,395                              1,317
# 1996-01-01      6                149,136                              1,374
# 1997-01-01      7                151,397                              1,483
# 1998-01-01      8                153,883                              1,594
# 1999-01-01      9                156,917                              1,668
# 2000-01-01     10                160,851                              1,783
# ...

# %%
wholecountry['city']='Whole Country'
wholecountry
new_df.reset_index(inplace=True)
# Out:
# <ipython-input-40-4fe66e4b6f1a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wholecountry['city']='Whole Country'

# %%
wholecountry.columns
# Out:
# Index(['WHOLE COUNTRY Population 31 Dec',
#        'WHOLE COUNTRY Citizens of foreign countries',
#        'WHOLE COUNTRY Persons born abroad',
#        'WHOLE COUNTRY Foreign-language speakers',
#        'WHOLE COUNTRY Persons with foreign background',
#        'WHOLE COUNTRY Share of foreign citizens, %',
#        'WHOLE COUNTRY Share of persons born abroad, %',
#        'WHOLE COUNTRY Share of foreign-language speakers, %',
#        'WHOLE COUNTRY Share of persons with foreign background , %',
#        'WHOLE COUNTRY Share of foreign citizens among foreign citizens in the whole country, %',
#        'WHOLE COUNTRY Share of persons born abroad among persons born abroad in the whole country, %',
#        'WHOLE COUNTRY Share of foreign-language speakers among foreign-language speakers in the whole country, %',
#        'WHOLE COUNTRY Share of persons with foreign background among persons with foreign backgr. in the whole country, %',
#        'city'],
#       dtype='object')

# %%
wholecountry1=wholecountry.groupby(["Year","city"])[['WHOLE COUNTRY Population 31 Dec',
       'WHOLE COUNTRY Citizens of foreign countries',
       'WHOLE COUNTRY Persons born abroad',
       'WHOLE COUNTRY Foreign-language speakers',
       'WHOLE COUNTRY Persons with foreign background',
       'WHOLE COUNTRY Share of foreign citizens, %',
       'WHOLE COUNTRY Share of persons born abroad, %',
       'WHOLE COUNTRY Share of foreign-language speakers, %',
       'WHOLE COUNTRY Share of persons with foreign background , %',
       'WHOLE COUNTRY Share of foreign citizens among foreign citizens in the whole country, %',
       'WHOLE COUNTRY Share of persons born abroad among persons born abroad in the whole country, %',
       'WHOLE COUNTRY Share of foreign-language speakers among foreign-language speakers in the whole country, %',
       'WHOLE COUNTRY Share of persons with foreign background among persons with foreign backgr. in the whole country, %',]].sum().unstack().swaplevel(0,1,1)
wholecountry1
# Out:
# city                         Whole Country  \
#            WHOLE COUNTRY Population 31 Dec
# Year
# 1990-01-01                       4,998,478
# 1991-01-01                       5,029,002
# 1992-01-01                       5,054,982
# 1993-01-01                       5,077,912
# 1994-01-01                       5,098,754
# 1995-01-01                       5,116,826
# 1996-01-01                       5,132,320
# 1997-01-01                       5,147,349
# 1998-01-01                       5,159,646
# 1999-01-01                       5,171,302
# 2000-01-01                       5,181,115
# 2001-01-01                       5,194,901
# 2002-01-01                       5,206,295
# 2003-01-01                       5,219,732
# 2004-01-01                       5,236,611
# 2005-01-01                       5,255,580
# 2006-01-01                       5,276,955
# 2007-01-01                       5,300,484
# 2008-01-01                       5,326,314
# 2009-01-01                       5,351,427
# ...

# %%
Tampere['city']='Tampere'
#new_df.set_index(["Year","city"]).unstack().swaplevel(0,1,1)
Tampere.columns
# Out:
# <ipython-input-49-2e437cd67f77>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Tampere['city']='Tampere'
# Index(['Tampere Population 31 Dec', 'Tampere Citizens of foreign countries',
#        'Tampere Persons born abroad', 'Tampere Foreign-language speakers',
#        'Tampere Persons with foreign background',
#        'Tampere Share of foreign citizens, %',
#        'Tampere Share of persons born abroad, %',
#        'Tampere Share of foreign-language speakers, %',
#        'Tampere Share of persons with foreign background , %',
#        'Tampere Share of foreign citizens among foreign citizens in the whole country, %',
#        'Tampere Share of persons born abroad among persons born abroad in the whole country, %',
# ...

# %%
Tampere1=Tampere.groupby(["Year","city"])[['Tampere Population 31 Dec', 'Tampere Citizens of foreign countries',
       'Tampere Persons born abroad', 'Tampere Foreign-language speakers',
       'Tampere Persons with foreign background',
       'Tampere Share of foreign citizens, %',
       'Tampere Share of persons born abroad, %',
       'Tampere Share of foreign-language speakers, %',
       'Tampere Share of persons with foreign background , %',
       'Tampere Share of foreign citizens among foreign citizens in the whole country, %',
       'Tampere Share of persons born abroad among persons born abroad in the whole country, %',
       'Tampere Share of foreign-language speakers among foreign-language speakers in the whole country, %',
       'Tampere Share of persons with foreign background among persons with foreign backgr. in the whole country, %',]].sum().unstack().swaplevel(0,1,1)
Tampere1
# Out:
# city                         Tampere                                        \
#            Tampere Population 31 Dec Tampere Citizens of foreign countries
# Year
# 1990-01-01                   172,560                                   936
# 1991-01-01                   173,797                                 1,249
# 1992-01-01                   174,859                                 1,517
# 1993-01-01                   176,149                                 1,858
# 1994-01-01                   179,251                                 2,256
# 1995-01-01                   182,742                                 2,709
# 1996-01-01                   186,026                                 3,070
# 1997-01-01                   188,726                                 3,563
# 1998-01-01                   191,254                                 3,791
# 1999-01-01                   193,174                                 4,053
# ...

# %%
Helsinki['city']='Helsinki'
Turku['city']='Turku'
Helsinki.columns
Helsinki1=Helsinki.groupby(["Year","city"])[['Helsinki Population 31 Dec', 'Helsinki Citizens of foreign countries',
       'Helsinki Persons born abroad', 'Helsinki Foreign-language speakers',
       'Helsinki Persons with foreign background',
       'Helsinki Share of foreign citizens, %',
       'Helsinki Share of persons born abroad, %',
       'Helsinki Share of foreign-language speakers, %',
       'Helsinki Share of persons with foreign background , %',
       'Helsinki Share of foreign citizens among foreign citizens in the whole country, %',
       'Helsinki Share of persons born abroad among persons born abroad in the whole country, %',
       'Helsinki Share of foreign-language speakers among foreign-language speakers in the whole country, %',
       'Helsinki Share of persons with foreign background among persons with foreign backgr. in the whole country, %',]].sum().unstack().swaplevel(0,1,1)
Helsinki1
# Out:
# <ipython-input-52-b34d996a0690>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Helsinki['city']='Helsinki'
# <ipython-input-52-b34d996a0690>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Turku['city']='Turku'
# city                         Helsinki                                         \
#            Helsinki Population 31 Dec Helsinki Citizens of foreign countries
# Year
# 1990-01-01                    492,400                                  6,883
# ...

# %%
Turku.columns
Turku1=Turku.groupby(["Year","city"])[['Turku Population 31 Dec', 'Turku Citizens of foreign countries',
       'Turku Persons born abroad', 'Turku Foreign-language speakers',
       'Turku Persons with foreign background',
       'Turku Share of foreign citizens, %',
       'Turku Share of persons born abroad, %',
       'Turku Share of foreign-language speakers, %',
       'Turku Share of persons with foreign background , %',
       'Turku Share of foreign citizens among foreign citizens in the whole country, %',
       'Turku Share of persons born abroad among persons born abroad in the whole country, %',
       'Turku Share of foreign-language speakers among foreign-language speakers in the whole country, %',
       'Turku Share of persons with foreign background among persons with foreign backgr. in the whole country, %',]].sum().unstack().swaplevel(0,1,1)
Turku1
# Out:
# city                         Turku                                      \
#            Turku Population 31 Dec Turku Citizens of foreign countries
# Year
# 1990-01-01                 159,180                               1,335
# 1991-01-01                 159,403                               1,813
# 1992-01-01                 159,916                               2,388
# 1993-01-01                 160,390                               2,901
# 1994-01-01                 162,370                               3,370
# 1995-01-01                 164,744                               3,945
# 1996-01-01                 166,929                               4,461
# 1997-01-01                 168,772                               5,099
# 1998-01-01                 170,931                               5,834
# 1999-01-01                 172,107                               6,205
# 2000-01-01                 172,561                               6,461
# ...

# %%
new_data=pd.concat([Tampere1,Turku1,Helsinki1],axis=1)
new_data
# Out:
# city                         Tampere                                        \
#            Tampere Population 31 Dec Tampere Citizens of foreign countries
# Year
# 1990-01-01                   172,560                                   936
# 1991-01-01                   173,797                                 1,249
# 1992-01-01                   174,859                                 1,517
# 1993-01-01                   176,149                                 1,858
# 1994-01-01                   179,251                                 2,256
# 1995-01-01                   182,742                                 2,709
# 1996-01-01                   186,026                                 3,070
# 1997-01-01                   188,726                                 3,563
# 1998-01-01                   191,254                                 3,791
# 1999-01-01                   193,174                                 4,053
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 30 entries, 1990-01-01 to 2019-01-01
# Columns: 6864 entries, WHOLE COUNTRY Population 31 Dec to FI200 Åland Share of persons with foreign background among persons with foreign backgr. in the whole country, %
# dtypes: float64(4224), int64(2640)
# memory usage: 1.6 MB

# %%
#checking the average of Foreigners coming to Finland since 1990
data.iloc[:,2].mean()
# Out:
# 134037.53333333333

# %%
#plotting the trend of foreigners moving to Finland since 1990
import matplotlib.pyplot as plt
#%matplotlib.pyplot as plt
data.iloc[:,2].plot(kind='bar',title='foreigners moving to Finland trend');
# this trend shows that there has always been increase in number of foreigners moving to Finland every year

# %%
#population trend in Finland
data.iloc[:,0].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-257-9e299ea471a3> in <module>
#       1 #population trend in Finland
# ----> 2 data.iloc[:,0].plot()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     947                     data.columns = label_name
#     948
# --> 949         return plot_backend.plot(data, kind=kind, **kwargs)
#     950
#     951     __call__.__doc__ = __doc__
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ...

# %%
#checking the average change in population from 1990 to 2019
#a=data.iloc[:,0].resample('10Y').mean()
data.iloc[:,0].pct_change(1)*100
#a.reset_index().iloc[:,0].pct_change()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-276-43bda48924ac> in <module>
#       1 #checking the average change in population from 1990 to 2019
#       2 #a=data.iloc[:,0].resample('10Y').mean()
# ----> 3 data.iloc[:,0].pct_change(1)*100
#       4 #a.reset_index().iloc[:,0].pct_change()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in pct_change(self, periods, fill_method, limit, freq, **kwargs)
#   10239             data = _data
#   10240
# > 10241         rs = data.div(data.shift(periods=periods, freq=freq, axis=axis, **kwargs)) - 1
#   10242         if freq is not None:
#   10243             # Shift method is implemented differently when freq is not None
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/__init__.py in flex_wrapper(self, other, level, fill_value, axis)
#     411
# ...

# %%
#no duplicate values were found in the dataset
data.duplicated()
# Out:
# Year
# 1990-01-01    False
# 1991-01-01    False
# 1992-01-01    False
# 1993-01-01    False
# 1994-01-01    False
# 1995-01-01    False
# 1996-01-01    False
# 1997-01-01    False
# 1998-01-01    False
# 1999-01-01    False
# 2000-01-01    False
# 2001-01-01    False
# 2002-01-01    False
# 2003-01-01    False
# 2004-01-01    False
# 2005-01-01    False
# 2006-01-01    False
# 2007-01-01    False
# 2008-01-01    False
# 2009-01-01    False
# 2010-01-01    False
# 2011-01-01    False
# 2012-01-01    False
# 2013-01-01    False
# 2014-01-01    False
# 2015-01-01    False
# 2016-01-01    False
# 2017-01-01    False
# 2018-01-01    False
# 2019-01-01    False
# dtype: bool
